# %% [markdown]
# <a href="https://colab.research.google.com/github/ZataraHere/100-Days-of-Machine-Learning/blob/main/Practice/Cardivascular_disease_model_dev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/cardio_train.csv',sep=';')

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df['age']=np.round(df['age']/365)

# %%
sns.histplot(data=df, x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data=df, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.histplot(data=df,kde=True, x='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.boxplot(data=df, x='height')
# Out:
# <Axes: xlabel='height'>

# %%
sns.histplot(data=df, x='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.boxplot(data=df, x='weight')
# Out:
# <Axes: xlabel='weight'>

# %%
sns.histplot(data=df, x='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.boxplot(data=df, x='ap_hi')
# Out:
# <Axes: xlabel='ap_hi'>

# %%
sns.histplot(data=df, x='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.boxplot(data=df, x='ap_lo')
# Out:
# <Axes: xlabel='ap_lo'>

# %%
sns.catplot(kind='count', data=df, x='gender')

# %%
sns.catplot(kind='count', data=df, x='cholesterol')

# %%
sns.catplot(kind='count', data=df, x='gluc')

# %%
sns.catplot(kind='count', data=df, x='smoke')

# %%
sns.catplot(kind='count', data=df, x='alco')

# %%
sns.catplot(kind='count', data=df, x='active')

# %%
sns.catplot(kind='count', data=df, x='cardio')

# %%
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %%
df.var()
# Out:
# id             8.323976e+08
# age            6.087331e+06
# gender         2.273745e-01
# height         6.740617e+01
# weight         2.072378e+02
# ap_hi          2.371952e+04
# ap_lo          3.552189e+04
# cholesterol    4.627405e-01
# gluc           3.274933e-01
# smoke          8.036307e-02
# alco           5.088079e-02
# active         1.577512e-01
# cardio         2.500035e-01
# dtype: float64

# %%
df.skew()
# Out:
# id             -0.001278
# age            -0.307055
# gender          0.630960
# height         -0.642187
# weight          1.012070
# ap_hi          85.296214
# ap_lo          32.114083
# cholesterol     1.587123
# gluc            2.397462
# smoke           2.905867
# alco            3.956607
# active         -1.529473
# cardio          0.001200
# dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
sns.relplot(x= 'age', y= 'height', data = df)

# %%
sns.relplot(x= 'age', y= 'weight',data = df)

# %%
sns.relplot(x= 'weight', y= 'height',data = df)
